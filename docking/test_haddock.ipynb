# %%
from haddock.clis import cli
from configs.build_config import build_config

motif_specs = "[10-40/C24-51/10-40]"
residue_specs = [[463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492]]

out_dir = 'run_test'
config_file = '/home/mubale/functional_eval/docking/configs/docking-protein-protein-test.cfg'
ambig_file = "configs/ambig_fname.tbl"
molecules = ['/home/xchen/projects/salt/results_rfdiffusion_motif_20241018230935/designability_eval/designs/rf_design_0.pdb', '/home/mubale/functional_eval/docking/configs/8hgo.pdb']

#cfg = build_config(out_dir, config_file, ambig_file, molecules, motif_specs, residue_specs)
cli.main(workflow = config_file)
# Out:
# [2024-10-24 20:27:03,160 cli INFO]
# ##############################################
# #                                            #
# #                 HADDOCK3                   #
# #                                            #
# ##############################################
#
# !! Some of the HADDOCK3 components use CNS (Crystallographic and NMR System) which is free of use for non-profit applications. !!
# !! For commercial use it is your own responsibility to have a proper license. !!
# !! For details refer to the DISCLAIMER file in the HADDOCK3 repository. !!
#
# Starting HADDOCK3 v2024.10.0b6 on 2024-10-24 20:27:00
#
# Python 3.10.14 | packaged by conda-forge | (main, Mar 20 2024, 12:45:18) [GCC 12.3.0]
#
# [2024-10-24 20:27:13,493 libworkflow INFO] Reading instructions step 0_topoaa
# [2024-10-24 20:27:13,494 libworkflow INFO] Reading instructions step 1_rigidbody
# [2024-10-24 20:27:13,496 libworkflow INFO] Reading instructions step 2_seletop
# [2024-10-24 20:27:13,497 libworkflow INFO] Reading instructions step 3_flexref
# [2024-10-24 20:27:13,498 libworkflow INFO] Reading instructions step 4_emref
# [2024-10-24 20:27:13,499 libworkflow INFO] Reading instructions step 5_clustfcc
# [2024-10-24 20:27:13,500 libworkflow INFO] Reading instructions step 6_caprieval
# [2024-10-24 20:27:13,540 base_cns_module INFO] Running [topoaa] module
# [2024-10-24 20:27:13,542 __init__ INFO] [topoaa] Molecule 1: e2aP_1F3G.pdb
# [2024-10-24 20:27:13,546 __init__ INFO] [topoaa] Sanitizing molecule e2aP_1F3G.pdb
# [2024-10-24 20:27:13,558 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,559 __init__ INFO] [topoaa] Molecule 2: hpr_ensemble.pdb
# [2024-10-24 20:27:13,574 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_1.pdb
# [2024-10-24 20:27:13,583 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,584 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_2.pdb
# [2024-10-24 20:27:13,593 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,593 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_3.pdb
# [2024-10-24 20:27:13,602 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,603 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_4.pdb
# [2024-10-24 20:27:13,612 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,613 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_5.pdb
# [2024-10-24 20:27:13,622 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,623 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_6.pdb
# [2024-10-24 20:27:13,632 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,633 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_7.pdb
# [2024-10-24 20:27:13,642 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,643 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_8.pdb
# [2024-10-24 20:27:13,652 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,653 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_9.pdb
# [2024-10-24 20:27:13,662 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,663 __init__ INFO] [topoaa] Sanitizing molecule hpr_ensemble_10.pdb
# [2024-10-24 20:27:13,673 __init__ INFO] [topoaa] Topology CNS input created
# [2024-10-24 20:27:13,674 __init__ INFO] [topoaa] Running CNS Jobs n=11
# [2024-10-24 20:27:13,675 libutil INFO] Selected 11 cores to process 11 jobs, with 56 maximum available cores.
# [2024-10-24 20:27:13,680 libparallel INFO] Using 11 cores
# [2024-10-24 20:27:15,138 libparallel INFO] 11 tasks finished
# [2024-10-24 20:27:15,141 __init__ INFO] [topoaa] CNS jobs have finished
# [2024-10-24 20:27:15,163 base_cns_module INFO] Module [topoaa] finished.
# [2024-10-24 20:27:15,165 __init__ INFO] [topoaa] took 2 seconds
# [2024-10-24 20:27:16,284 base_cns_module INFO] Running [rigidbody] module
# [2024-10-24 20:27:16,287 __init__ INFO] [rigidbody] crossdock=true
# [2024-10-24 20:27:16,288 __init__ INFO] [rigidbody] Preparing jobs...
# [2024-10-24 20:27:16,292 libutil INFO] Selected 40 cores to process 1000 jobs, with 56 maximum available cores.
# [2024-10-24 20:27:16,295 libparallel INFO] Using 40 cores
# [2024-10-24 20:27:16,821 libparallel INFO] 1000 tasks finished
# [2024-10-24 20:27:16,830 __init__ INFO] [rigidbody] Preparation took 0.541217 seconds
# [2024-10-24 20:27:16,900 __init__ INFO] [rigidbody] Running CNS Jobs n=1000
# [2024-10-24 20:27:16,902 libutil INFO] Selected 40 cores to process 1000 jobs, with 56 maximum available cores.
# [2024-10-24 20:27:16,907 libparallel INFO] Using 40 cores
# [2024-10-24 20:31:05,801 libparallel INFO] 1000 tasks finished
# [2024-10-24 20:31:05,805 __init__ INFO] [rigidbody] CNS jobs have finished
# [2024-10-24 20:31:06,770 base_cns_module INFO] Module [rigidbody] finished.
# [2024-10-24 20:31:06,771 __init__ INFO] [rigidbody] took 3 minutes and 50 seconds
# [2024-10-24 20:31:06,958 __init__ INFO] Running [seletop] module
# [2024-10-24 20:31:07,186 __init__ INFO] Module [seletop] finished.
# [2024-10-24 20:31:07,187 __init__ INFO] [seletop] took 0 seconds
# [2024-10-24 20:31:08,343 base_cns_module INFO] Running [flexref] module
# [2024-10-24 20:31:09,303 __init__ INFO] [flexref] Running CNS Jobs n=200
# [2024-10-24 20:31:09,304 libutil INFO] Selected 40 cores to process 200 jobs, with 56 maximum available cores.
# [2024-10-24 20:31:09,307 libparallel INFO] Using 40 cores
# [2024-10-24 20:31:11,585 libparallel INFO] The workers terminated in a controlled way
# [2024-10-24 20:31:11,618 libworkflow INFO] You have halted subprocess execution by hitting Ctrl+c
# [2024-10-24 20:31:11,622 libworkflow INFO] Exiting...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/haddock/libs/libworkflow.py:162, in Step.execute(self)
#     161     self.module.save_config(Path(self.working_path, "params.cfg"))  # type: ignore
# --> 162     self.module.run()  # type: ignore
#     163 except KeyboardInterrupt:
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/haddock/modules/base_cns_module.py:61, in BaseCNSModule.run(self, **params)
#      60 with working_directory(self.path):
# ---> 61     self._run()
#      63 log.info(f'Module [{self.name}] finished.')
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/haddock/modules/refinement/flexref/__init__.py:142, in HaddockModule._run(self)
#     141 engine = Engine(jobs)
# --> 142 engine.run()
#     143 self.log("CNS jobs have finished")
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/haddock/libs/libparallel.py:201, in Scheduler.run(self)
#     198 # this raises sends the error to libs.libworkflow.Step
#     199 # if Scheduler is used independently the error will propagate to
#     200 # whichever has to catch it
# --> 201 raise err
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/haddock/libs/libparallel.py:181, in Scheduler.run(self)
#     180 while completed_workers < num_workers:
# --> 181     result = self.queue.get()
#     182     if isinstance(result, str) and result.endswith("_done"):
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/multiprocessing/queues.py:103, in Queue.get(self, block, timeout)
#     102 with self._rlock:
# --> 103     res = self._recv_bytes()
#     104 self._sem.release()
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/multiprocessing/connection.py:216, in _ConnectionBase.recv_bytes(self, maxlength)
#     215     raise ValueError("negative maxlength")
# --> 216 buf = self._recv_bytes(maxlength)
#     217 if buf is None:
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/multiprocessing/connection.py:414, in Connection._recv_bytes(self, maxsize)
#     413 def _recv_bytes(self, maxsize=None):
# --> 414     buf = self._recv(4)
#     415     size, = struct.unpack("!i", buf.getvalue())
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/multiprocessing/connection.py:379, in Connection._recv(self, size, read)
#     378 while remaining > 0:
# --> 379     chunk = read(handle, remaining)
#     380     n = len(chunk)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[1], line 13
#      12 #cfg = build_config(out_dir, config_file, ambig_file, molecules, motif_specs, residue_specs)
# ---> 13 cli.main(workflow = config_file)
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/haddock/clis/cli.py:195, in main(workflow, restart, extend_run, setup_only, log_level)
#     194 # Main loop of execution
# --> 195 workflow.run()
#     196 if other_params["postprocess"]:
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/haddock/libs/libworkflow.py:43, in WorkflowManager.run(self)
#      42 try:
# ---> 43     step.execute()
#      44 except HaddockTermination:
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/haddock/libs/libworkflow.py:166, in Step.execute(self)
#     165     log.info("Exiting...")
# --> 166     sys.exit(1)
#     168 end = time()
#
# SystemExit: 1
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2145, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2142 if exception_only:
#    2143     stb = ['An exception has occurred, use %tb to see '
#    2144            'the full traceback.\n']
# -> 2145     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2146                                                      value))
#    2147 else:
#    2149     def contains_exceptiongroup(val):
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/IPython/core/ultratb.py:1454, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1452 else:
#    1453     self.tb = etb
# -> 1454 return FormattedTB.structured_traceback(
#    1455     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1456 )
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/IPython/core/ultratb.py:1345, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1342 mode = self.mode
#    1343 if mode in self.verbose_modes:
#    1344     # Verbose modes need a full traceback
# -> 1345     return VerboseTB.structured_traceback(
#    1346         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1347     )
#    1348 elif mode == 'Minimal':
#    1349     return ListTB.get_exception_only(self, etype, value)
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/IPython/core/ultratb.py:1192, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1183 def structured_traceback(
#    1184     self,
#    1185     etype: type,
#    (...)
#    1189     number_of_lines_of_context: int = 5,
#    1190 ):
#    1191     """Return a nice text document describing the traceback."""
# -> 1192     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                            tb_offset)
#    1195     colors = self.Colors  # just a shorthand + quicker name lookup
#    1196     colorsnormal = colors.Normal  # used a lot
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/IPython/core/ultratb.py:1082, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1079 assert isinstance(tb_offset, int)
#    1080 head = self.prepare_header(str(etype), self.long_header)
#    1081 records = (
# -> 1082     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1083 )
#    1085 frames = []
#    1086 skipped = 0
#
# File ~/miniconda3/envs/salt_env/lib/python3.10/site-packages/IPython/core/ultratb.py:1150, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1148 while cf is not None:
#    1149     try:
# -> 1150         mod = inspect.getmodule(cf.tb_frame)
#    1151         if mod is not None:
#    1152             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
